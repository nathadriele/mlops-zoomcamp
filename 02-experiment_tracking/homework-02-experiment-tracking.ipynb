# %%
import mlflow

# %%
# !python preprocess_data.py --raw_data_path ./data --dest_path ./output

# %%
import os

output_folder = './output'

files = os.listdir(output_folder)
print("Files saved in", output_folder, ":")
for file in files:
    print(file)
# Out:
# Files saved in ./output :
# dv.pkl
# test.pkl
# train.pkl
# val.pkl

# %%
# !python train.py
# Out:
# 2

# %% [markdown]
# ###!mlflow server --host 127.0.0.1 --port 5000

# %%
# !python hpo.py
# Out:
#   0%|          | 0/15 [00:00<?, ?trial/s, best loss=?]
#   7%|6         | 1/15 [00:18<04:13, 18.11s/trial, best loss: 5.370086069268862]
#  13%|#3        | 2/15 [00:19<01:47,  8.29s/trial, best loss: 5.370086069268862]
#  20%|##        | 3/15 [00:21<01:04,  5.41s/trial, best loss: 5.370086069268862]
#  27%|##6       | 4/15 [00:40<01:56, 10.60s/trial, best loss: 5.357490752366866]
#  33%|###3      | 5/15 [00:49<01:40, 10.06s/trial, best loss: 5.357490752366866]
#  40%|####      | 6/15 [01:21<02:37, 17.49s/trial, best loss: 5.354695072530291]
#  47%|####6     | 7/15 [01:52<02:56, 22.04s/trial, best loss: 5.354695072530291]
#  53%|#####3    | 8/15 [01:55<01:52, 16.08s/trial, best loss: 5.354695072530291]
#  60%|######    | 9/15 [02:14<01:42, 17.04s/trial, best loss: 5.354695072530291]
#  67%|######6   | 10/15 [02:30<01:23, 16.71s/trial, best loss: 5.354695072530291]
#  73%|#######3  | 11/15 [02:43<01:01, 15.33s/trial, best loss: 5.335419588556921]
#  80%|########  | 12/15 [02:52<00:40, 13.66s/trial, best loss: 5.335419588556921]
#  87%|########6 | 13/15 [02:56<00:21, 10.54s/trial, best loss: 5.335419588556921]
#  93%|#########3| 14/15 [03:07<00:10, 10.83s/trial, best loss: 5.335419588556921]
# 100%|##########| 15/15 [03:25<00:00, 13.03s/trial, best loss: 5.335419588556921]
# 100%|##########| 15/15 [03:25<00:00, 13.73s/trial, best loss: 5.335419588556921]
# 2024/05/26 16:50:44 INFO mlflow.tracking.fluent: Experiment with name 'random-forest-hyperopt' does not exist. Creating a new experiment.
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
#
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(

# %%
# !python register_model.py
# Out:
# The test RMSE for the best model is: 5.567408012462019
# 2024/05/26 16:56:44 INFO mlflow.tracking.fluent: Experiment with name 'random-forest-best-models' does not exist. Creating a new experiment.
# 2024/05/26 16:56:44 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.
# 2024/05/26 16:56:45 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# 2024/05/26 16:57:00 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\_distutils_hack\__init__.py:26: UserWarning: Setuptools is replacing distutils."
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 2024/05/26 16:57:19 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 2024/05/26 16:57:48 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 2024/05/26 16:58:06 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# 2024/05/26 16:58:30 WARNING mlflow.sklearn: Failed to log training dataset information to MLflow Tracking. Reason: 'numpy.ndarray' object has no attribute 'toarray'
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# C:\Users\Mestra\miniconda3\envs\mlflow\lib\site-packages\sklearn\metrics\_regression.py:492: FutureWarning: 'squared' is deprecated in version 1.4 and will be removed in 1.6. To calculate the root mean squared error, use the function'root_mean_squared_error'.
#   warnings.warn(
# Successfully registered model 'nyc-taxi-regressor'.
# 2024/05/26 16:58:57 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: nyc-taxi-regressor, version 1
# Created version '1' of model 'nyc-taxi-regressor'.
